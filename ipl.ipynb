# %%
import pandas as pd
df=pd.read_csv("batsman_season_record.csv")
df.head()
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   batsman  5 non-null      object
#  1   2015     5 non-null      int64
#  2   2016     5 non-null      int64
#  3   2017     5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes
# Index(['batsman', '2015', '2016', '2017'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.bar(df["batsman"],df["2017"],label="2017")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(df["batsman"],df["2017"],label="2017")
plt.bar(df["batsman"],df["2016"],bottom=df["2017"])
plt.bar(df["batsman"],df["2015"],bottom=df["2016"]+df["2017"])
plt.legend()

# %%
df.plot(kind="bar",stacked=True)
# Out:
# <Axes: >

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
#using matplotlib
plt.hist(df['age'],bins=20)#hist tells frequency
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %%
#how histogram is similar to desnsity plot?
df["age"].plot(kind='kde')#kde tells probability density function
# Out:
# <Axes: ylabel='Density'>

# %%
#pi chart
marks=[98,97,99,100,91]
subjects=["english","physics","chemistry","maths","computer"]
plt.pie(marks)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c2faae67b0>,
# ...
#  [Text(0.8857119026021673, 0.6523146676174385, ''),
#   Text(-0.35344294845249297, 1.0416708127759022, ''),
#   Text(-1.0996307905402336, -0.028497798087943397, ''),
#   Text(-0.27838711567254176, -1.0641901210909277, ''),
#   Text(0.9143690532561306, -0.6114975342938739, '')])

# %%
#no of passenger travelling in each class
df['pclass'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>
